# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler

# %%
customers = pd.read_csv("/content/Customers.csv")
products = pd.read_csv("/content/Products.csv")
transactions = pd.read_csv("/content/Transactions.csv")

# %%
merged_data = pd.read_csv("/content/Cleaned_Merged_Data.csv")

# %%
merged_data
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0          T00001      C0199      P067  2024-08-25 12:38:23         1
# 1          T00112      C0146      P067  2024-05-27 22:23:54         1
# 2          T00166      C0127      P067  2024-04-25 07:38:55         1
# 3          T00272      C0087      P067  2024-03-26 22:55:37         2
# 4          T00363      C0070      P067  2024-03-21 15:10:10         3
# ..            ...        ...       ...                  ...       ...
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue  Price_x          CustomerName         Region  SignupDate  \
# 0        300.68   300.68        Andrea Jenkins         Europe  2022-12-03
# 1        300.68   300.68       Brittany Harvey           Asia  2024-09-04
# 2        300.68   300.68       Kathryn Stevens         Europe  2024-04-04
# 3        601.36   300.68       Travis Campbell  South America  2024-04-11
# 4        902.04   300.68         Timothy Perez         Europe  2022-03-15
# ..          ...      ...                   ...            ...         ...
# 995      459.86   459.86            Jacob Holt  South America  2022-01-22
# 996     1379.58   459.86  Mrs. Kimberly Wright  North America  2024-04-07
# 997     1839.44   459.86          Tyler Haynes  North America  2024-09-21
# 998      919.72   459.86       Joshua Hamilton           Asia  2024-11-11
# 999      459.86   459.86        Michele Cooley  North America  2024-02-05
#
#                          ProductName     Category  Price_y  Year  Month  \
# 0    ComfortLiving Bluetooth Speaker  Electronics   300.68  2024      8
# 1    ComfortLiving Bluetooth Speaker  Electronics   300.68  2024      5
# 2    ComfortLiving Bluetooth Speaker  Electronics   300.68  2024      4
# 3    ComfortLiving Bluetooth Speaker  Electronics   300.68  2024      3
# 4    ComfortLiving Bluetooth Speaker  Electronics   300.68  2024      3
# ..                               ...          ...      ...   ...    ...
# 995             SoundWave Smartwatch  Electronics   459.86  2024     10
# 996             SoundWave Smartwatch  Electronics   459.86  2024      6
# 997             SoundWave Smartwatch  Electronics   459.86  2024      4
# 998             SoundWave Smartwatch  Electronics   459.86  2024      9
# 999             SoundWave Smartwatch  Electronics   459.86  2024      4
#
#      CustomerTenure
# 0             777.0
# 1             834.0
# 2              49.0
# 3             534.0
# 4             584.0
# ..              ...
# 995             NaN
# 996             NaN
# 997             NaN
# 998             NaN
# 999             NaN
#
# [1000 rows x 16 columns]

# %%
merged_data.rename(columns={"Price_x": "TransactionPrice", "Price_y": "ProductPrice"}, inplace=True)

# %%
merged_data
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0          T00001      C0199      P067  2024-08-25 12:38:23         1
# 1          T00112      C0146      P067  2024-05-27 22:23:54         1
# 2          T00166      C0127      P067  2024-04-25 07:38:55         1
# 3          T00272      C0087      P067  2024-03-26 22:55:37         2
# 4          T00363      C0070      P067  2024-03-21 15:10:10         3
# ..            ...        ...       ...                  ...       ...
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue  TransactionPrice          CustomerName         Region  \
# 0        300.68            300.68        Andrea Jenkins         Europe
# 1        300.68            300.68       Brittany Harvey           Asia
# 2        300.68            300.68       Kathryn Stevens         Europe
# 3        601.36            300.68       Travis Campbell  South America
# 4        902.04            300.68         Timothy Perez         Europe
# ..          ...               ...                   ...            ...
# 995      459.86            459.86            Jacob Holt  South America
# 996     1379.58            459.86  Mrs. Kimberly Wright  North America
# 997     1839.44            459.86          Tyler Haynes  North America
# 998      919.72            459.86       Joshua Hamilton           Asia
# 999      459.86            459.86        Michele Cooley  North America
#
#      SignupDate                      ProductName     Category  ProductPrice  \
# 0    2022-12-03  ComfortLiving Bluetooth Speaker  Electronics        300.68
# 1    2024-09-04  ComfortLiving Bluetooth Speaker  Electronics        300.68
# 2    2024-04-04  ComfortLiving Bluetooth Speaker  Electronics        300.68
# 3    2024-04-11  ComfortLiving Bluetooth Speaker  Electronics        300.68
# 4    2022-03-15  ComfortLiving Bluetooth Speaker  Electronics        300.68
# ..          ...                              ...          ...           ...
# 995  2022-01-22             SoundWave Smartwatch  Electronics        459.86
# 996  2024-04-07             SoundWave Smartwatch  Electronics        459.86
# 997  2024-09-21             SoundWave Smartwatch  Electronics        459.86
# 998  2024-11-11             SoundWave Smartwatch  Electronics        459.86
# 999  2024-02-05             SoundWave Smartwatch  Electronics        459.86
#
#      Year  Month  CustomerTenure
# 0    2024      8           777.0
# 1    2024      5           834.0
# 2    2024      4            49.0
# 3    2024      3           534.0
# 4    2024      3           584.0
# ..    ...    ...             ...
# 995  2024     10             NaN
# 996  2024      6             NaN
# 997  2024      4             NaN
# 998  2024      9             NaN
# 999  2024      4             NaN
#
# [1000 rows x 16 columns]

# %%
# Aggregating customer-level features
customer_features = merged_data.groupby("CustomerID").agg({
    "TotalValue": "sum",  # Total spending
    "Quantity": "sum",    # Total quantity purchased
    "ProductID": "count", # Number of transactions
    "Category": lambda x: x.mode()[0],  # Most frequent category
    "TransactionPrice": "mean"          # Average transaction price
}).reset_index()

# %%
customer_features
# Out:
#     CustomerID  TotalValue  Quantity  ProductID  TransactionPrice  \
# 0        C0001   -0.061701 -0.122033  -0.011458          0.094670
# 1        C0002   -0.877744 -0.448000  -0.467494         -0.904016
# 2        C0003   -0.405857  0.203934  -0.467494         -1.094109
# 3        C0004    1.032547  1.670787   1.356650         -0.447702
# 4        C0005   -0.783929 -0.936951  -0.923530          0.285581
# ..         ...         ...       ...        ...               ...
# 194      C0196    0.829053 -0.122033  -0.467494          2.089604
# 195      C0197   -0.841689 -0.610984  -0.923530         -0.643077
# 196      C0198   -1.386975 -1.588886  -1.379566         -0.461100
# 197      C0199   -0.813993 -0.610984  -0.467494         -0.304206
# 198      C0200    0.706367  0.529902  -0.011458          0.356118
#
#            CustomerName  SignupDate  Region_Europe  Region_North America  \
# 0      Lawrence Carroll  2022-07-10          False                 False
# 1        Elizabeth Lutz  2022-02-13          False                 False
# 2        Michael Rivera  2024-03-07          False                 False
# 3    Kathleen Rodriguez  2022-10-09          False                 False
# 4           Laura Weber  2022-08-15          False                 False
# ..                  ...         ...            ...                   ...
# 194         Laura Watts  2022-06-07           True                 False
# 195    Christina Harvey  2023-03-21           True                 False
# 196         Rebecca Ray  2022-02-27           True                 False
# 197      Andrea Jenkins  2022-12-03           True                 False
# 198         Kelly Cross  2023-06-11          False                 False
#
#      Region_South America  Category_Clothing  Category_Electronics  \
# 0                    True              False                  True
# 1                   False               True                 False
# 2                    True              False                 False
# 3                    True              False                 False
# 4                   False              False                  True
# ..                    ...                ...                   ...
# 194                 False              False                 False
# 195                 False              False                  True
# 196                 False               True                 False
# 197                 False              False                  True
# 198                 False               True                 False
#
#      Category_Home Decor
# 0                  False
# 1                  False
# 2                   True
# 3                  False
# 4                  False
# ..                   ...
# 194                 True
# 195                False
# 196                False
# 197                False
# 198                False
#
# [199 rows x 13 columns]

# %%
# Add demographic features from the Customers dataset
customer_features = customer_features.merge(customers, on="CustomerID")

# %%
customer_features
# Out:
#     CustomerID  TotalValue  Quantity  ProductID  TransactionPrice  \
# 0        C0001   -0.061701 -0.122033  -0.011458          0.094670
# 1        C0002   -0.877744 -0.448000  -0.467494         -0.904016
# 2        C0003   -0.405857  0.203934  -0.467494         -1.094109
# 3        C0004    1.032547  1.670787   1.356650         -0.447702
# 4        C0005   -0.783929 -0.936951  -0.923530          0.285581
# ..         ...         ...       ...        ...               ...
# 194      C0196    0.829053 -0.122033  -0.467494          2.089604
# 195      C0197   -0.841689 -0.610984  -0.923530         -0.643077
# 196      C0198   -1.386975 -1.588886  -1.379566         -0.461100
# 197      C0199   -0.813993 -0.610984  -0.467494         -0.304206
# 198      C0200    0.706367  0.529902  -0.011458          0.356118
#
#            CustomerName  SignupDate  Region_Europe  Region_North America  \
# 0      Lawrence Carroll  2022-07-10          False                 False
# 1        Elizabeth Lutz  2022-02-13          False                 False
# 2        Michael Rivera  2024-03-07          False                 False
# 3    Kathleen Rodriguez  2022-10-09          False                 False
# 4           Laura Weber  2022-08-15          False                 False
# ..                  ...         ...            ...                   ...
# 194         Laura Watts  2022-06-07           True                 False
# 195    Christina Harvey  2023-03-21           True                 False
# 196         Rebecca Ray  2022-02-27           True                 False
# 197      Andrea Jenkins  2022-12-03           True                 False
# 198         Kelly Cross  2023-06-11          False                 False
#
#      Region_South America  Category_Clothing  Category_Electronics  \
# 0                    True              False                  True
# 1                   False               True                 False
# 2                    True              False                 False
# 3                    True              False                 False
# 4                   False              False                  True
# ..                    ...                ...                   ...
# 194                 False              False                 False
# 195                 False              False                  True
# 196                 False               True                 False
# 197                 False              False                  True
# 198                 False               True                 False
#
#      Category_Home Decor
# 0                  False
# 1                  False
# 2                   True
# 3                  False
# 4                  False
# ..                   ...
# 194                 True
# 195                False
# 196                False
# 197                False
# 198                False
#
# [199 rows x 13 columns]

# %%
# Normalize numerical features for similarity calculation
scaler = StandardScaler()
numerical_cols = ["TotalValue", "Quantity", "ProductID", "TransactionPrice"]
customer_features[numerical_cols] = scaler.fit_transform(customer_features[numerical_cols])

# %%
# Encode categorical variables (e.g., Region, Category)
customer_features = pd.get_dummies(customer_features, columns=["Region", "Category"], drop_first=True)

# %%
customer_features
# Out:
#     CustomerID  TotalValue  Quantity  ProductID  TransactionPrice  \
# 0        C0001   -0.061701 -0.122033  -0.011458          0.094670
# 1        C0002   -0.877744 -0.448000  -0.467494         -0.904016
# 2        C0003   -0.405857  0.203934  -0.467494         -1.094109
# 3        C0004    1.032547  1.670787   1.356650         -0.447702
# 4        C0005   -0.783929 -0.936951  -0.923530          0.285581
# ..         ...         ...       ...        ...               ...
# 194      C0196    0.829053 -0.122033  -0.467494          2.089604
# 195      C0197   -0.841689 -0.610984  -0.923530         -0.643077
# 196      C0198   -1.386975 -1.588886  -1.379566         -0.461100
# 197      C0199   -0.813993 -0.610984  -0.467494         -0.304206
# 198      C0200    0.706367  0.529902  -0.011458          0.356118
#
#            CustomerName  SignupDate  Region_Europe  Region_North America  \
# 0      Lawrence Carroll  2022-07-10          False                 False
# 1        Elizabeth Lutz  2022-02-13          False                 False
# 2        Michael Rivera  2024-03-07          False                 False
# 3    Kathleen Rodriguez  2022-10-09          False                 False
# 4           Laura Weber  2022-08-15          False                 False
# ..                  ...         ...            ...                   ...
# 194         Laura Watts  2022-06-07           True                 False
# 195    Christina Harvey  2023-03-21           True                 False
# 196         Rebecca Ray  2022-02-27           True                 False
# 197      Andrea Jenkins  2022-12-03           True                 False
# 198         Kelly Cross  2023-06-11          False                 False
#
#      Region_South America  Category_Clothing  Category_Electronics  \
# 0                    True              False                  True
# 1                   False               True                 False
# 2                    True              False                 False
# 3                    True              False                 False
# 4                   False              False                  True
# ..                    ...                ...                   ...
# 194                 False              False                 False
# 195                 False              False                  True
# 196                 False               True                 False
# 197                 False              False                  True
# 198                 False               True                 False
#
#      Category_Home Decor
# 0                  False
# 1                  False
# 2                   True
# 3                  False
# 4                  False
# ..                   ...
# 194                 True
# 195                False
# 196                False
# 197                False
# 198                False
#
# [199 rows x 13 columns]

# %%
# Computed cosine similarity for all
feature_matrix = customer_features.drop(columns=["CustomerID", "CustomerName", "SignupDate"]).values
similarity_matrix = cosine_similarity(feature_matrix)

# %%
# top-3 similar customers for the first 20 customers (C0001-C0020)
customer_ids = customer_features["CustomerID"].values[:20]  # Select only the first 20 customers
similarity_matrix_subset = similarity_matrix[:20, :]  # Slice the similarity matrix for the first 20 customers

# %%
customer_ids
# Out:
# array(['C0001', 'C0002', 'C0003', 'C0004', 'C0005', 'C0006', 'C0007',
#        'C0008', 'C0009', 'C0010', 'C0011', 'C0012', 'C0013', 'C0014',
#        'C0015', 'C0016', 'C0017', 'C0018', 'C0019', 'C0020'], dtype=object)

# %%
similarity_matrix_subset
# Out:
# array([[ 1.        ,  0.01158307,  0.33280652, ...,  0.06038232,
#          0.4227504 , -0.03783943],
#        [ 0.01158307,  1.        ,  0.44619905, ...,  0.78646749,
#          0.46707677, -0.07266188],
#        [ 0.33280652,  0.44619905,  1.        , ...,  0.24927496,
#          0.21746276, -0.21419784],
#        ...,
#        [-0.07961429, -0.29682875,  0.05604602, ..., -0.50017357,
#         -0.36903105,  0.41544539],
#        [ 0.01528338,  0.38611162,  0.19030112, ...,  0.49127127,
#          0.65145445, -0.41823892],
#        [ 0.2982471 ,  0.42239927,  0.08878485, ...,  0.72600362,
#          0.6546982 , -0.36952185]])

# %%
lookalike_map = {}
for i, customer_id in enumerate(customer_ids):
    # Get similarity scores for the current customer
    similarity_scores = similarity_matrix_subset[i, :]

    # Rank customers by similarity, excluding the current customer
    similar_indices = np.argsort(-similarity_scores)  # Sort in descending order
    similar_indices = similar_indices[similar_indices != i][:3]  # Exclude self and take top-3


    # Retrieve similar customers and their similarity scores
    similar_customers = [
        (customer_features["CustomerID"].iloc[idx], similarity_scores[idx]) for idx in similar_indices
    ]
    lookalike_map[customer_id] = similar_customers

# Convert the lookalike map into a DataFrame and save it
lookalike_data = []
for cust_id, lookalikes in lookalike_map.items():
    for lookalike, score in lookalikes:
        lookalike_data.append({"CustomerID": cust_id, "SimilarCustomerID": lookalike, "Score": score})

lookalike_df = pd.DataFrame(lookalike_data)
lookalike_df.to_csv("Lookalike.csv", index=False)

# %%
lookalike = pd.read_csv("/content/Lookalike.csv")

# %%
lookalike
# Out:
#    CustomerID SimilarCustomerID     Score
# 0       C0001             C0181  0.892036
# 1       C0001             C0190  0.827650
# 2       C0001             C0192  0.820003
# 3       C0002             C0088  0.950441
# 4       C0002             C0077  0.907828
# 5       C0002             C0144  0.886983
# 6       C0003             C0031  0.872445
# 7       C0003             C0025  0.867928
# 8       C0003             C0052  0.854926
# 9       C0004             C0165  0.983761
# 10      C0004             C0113  0.915299
# 11      C0004             C0175  0.909540
# 12      C0005             C0140  0.985768
# 13      C0005             C0186  0.980346
# 14      C0005             C0130  0.922950
# 15      C0006             C0168  0.933932
# 16      C0006             C0187  0.902086
# 17      C0006             C0011  0.852124
# 18      C0007             C0146  0.975293
# 19      C0007             C0115  0.967581
# 20      C0007             C0186  0.946228
# 21      C0008             C0090  0.865425
# 22      C0008             C0109  0.856316
# 23      C0008             C0065  0.854585
# 24      C0009             C0061  0.968214
# 25      C0009             C0198  0.944050
# 26      C0009             C0167  0.870461
# 27      C0010             C0111  0.943563
# 28      C0010             C0121  0.887333
# 29      C0010             C0062  0.873606
# 30      C0011             C0137  0.930662
# 31      C0011             C0191  0.875670
# 32      C0011             C0126  0.868581
# 33      C0012             C0163  0.958170
# 34      C0012             C0113  0.934169
# 35      C0012             C0104  0.934110
# 36      C0013             C0099  0.982439
# 37      C0013             C0108  0.891411
# 38      C0013             C0155  0.886104
# 39      C0014             C0097  0.961653
# 40      C0014             C0063  0.951609
# 41      C0014             C0060  0.948936
# 42      C0015             C0131  0.979201
# 43      C0015             C0058  0.961351
# 44      C0015             C0020  0.910291
# 45      C0016             C0042  0.879425
# 46      C0016             C0040  0.826430
# 47      C0016             C0183  0.813015
# 48      C0017             C0075  0.974804
# 49      C0017             C0041  0.918665
# 50      C0017             C0090  0.883506
# 51      C0018             C0046  0.839780
# 52      C0018             C0122  0.790749
# 53      C0018             C0068  0.768293
# 54      C0019             C0172  0.820184
# 55      C0019             C0119  0.780118
# 56      C0019             C0081  0.778559
# 57      C0020             C0140  0.937941
# 58      C0020             C0005  0.921797
# 59      C0020             C0131  0.914648
